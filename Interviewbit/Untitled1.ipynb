# %%
import time
import pyautogui
import webbrowser
import pandas as pd

# %%
facebook = pd.read_excel('/home/anuj/Downloads/facebook (1).xlsx')
facebook
# Out:
#     S.No.                                               Name  \
# 0       1             OpenSea NFT Collectors & NFT Giveaways
# 1       2                                     NFT ARTs INDIA
# 2       3                                            NFT Art
# 3       4                           NFT Artists & Collectors
# 4       5                                                NFT
# ..    ...                                                ...
# 88     89                                                Nft
# 89     90                                    NFT Marketplace
# 90     91                                         NFT Arabic
# 91     92  NFT Artists & Collectors | Rare Digital Art | ...
# 92     93                              NFT Crypto Hunters PH
#
#                                        NFT Group link  Unnamed: 3  \
# 0    https://www.facebook.com/groups/505960517173451/         NaN
# 1        https://www.facebook.com/groups/nftartindia/         NaN
# ...

# %%
groups_list = list(facebook['NFT Group link'])
groups_list
# Out:
# ['https://www.facebook.com/groups/505960517173451/',
#  'https://www.facebook.com/groups/nftartindia/',
#  'https://www.facebook.com/groups/1639769613026517/',
#  'https://www.facebook.com/groups/820791455457051/',
#  'https://www.facebook.com/groups/fbnfts/',
#  'https://www.facebook.com/groups/nftearth/',
#  'https://www.facebook.com/groups/nftfans/',
#  'https://www.facebook.com/groups/planetixworld/',
#  'https://www.facebook.com/groups/368841458358536/',
#  'https://www.facebook.com/groups/894430504548361/',
#  'https://www.facebook.com/groups/428633814598401/',
#  'https://www.facebook.com/groups/958869978066909/',
#  'https://www.facebook.com/groups/237665151736501/',
#  'https://www.facebook.com/groups/nftphilippines/',
#  'https://www.facebook.com/groups/436010028169025/',
#  'https://www.facebook.com/groups/nftcyrpto/',
#  'https://www.facebook.com/groups/nftgamingphcommunity/',
#  'https://www.facebook.com/groups/4693026054119936/',
# ...

# %%
def split(list_a, chunk_size):

  for i in range(0, len(list_a), chunk_size):
    yield list_a[i:i + chunk_size]

chunk_size = int(len(groups_list)/5)
group_list_01=list(split(groups_list, chunk_size))
group_list_01
# Out:
# [['https://www.facebook.com/groups/505960517173451/',
#   'https://www.facebook.com/groups/nftartindia/',
#   'https://www.facebook.com/groups/1639769613026517/',
#   'https://www.facebook.com/groups/820791455457051/',
#   'https://www.facebook.com/groups/fbnfts/',
#   'https://www.facebook.com/groups/nftearth/',
#   'https://www.facebook.com/groups/nftfans/',
#   'https://www.facebook.com/groups/planetixworld/',
#   'https://www.facebook.com/groups/368841458358536/',
#   'https://www.facebook.com/groups/894430504548361/',
#   'https://www.facebook.com/groups/428633814598401/',
#   'https://www.facebook.com/groups/958869978066909/',
#   'https://www.facebook.com/groups/237665151736501/',
#   'https://www.facebook.com/groups/nftphilippines/',
#   'https://www.facebook.com/groups/436010028169025/',
#   'https://www.facebook.com/groups/nftcyrpto/',
#   'https://www.facebook.com/groups/nftgamingphcommunity/',
#   'https://www.facebook.com/groups/4693026054119936/'],
# ...

# %%
b=webbrowser.get('firefox')
for url in group_list_01[0]:
    b.open(url)
    print("Waiting for 5 seconds\n")
    time.sleep(5)
    pyautogui.typewrite('')
    time.sleep(2)
    print("Writing post\n")
    pyautogui.typewrite("https://opensea.io/collection/hanumaan")
    time.sleep(4)
    pyautogui.keyDown('ctrl')
    pyautogui.keyDown('enter')
    pyautogui.keyUp('enter')
    pyautogui.keyUp('ctrl')

    time.sleep(3)

    pyautogui.write(['f6'])
    time.sleep(1)
# Out:
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
#
# Waiting for 5 seconds
#
# Writing post
